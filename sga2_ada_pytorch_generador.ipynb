# %% [markdown]
# # Generador StyleGAN ADA PyTorch

# %%
#@title Montar Google Drive
#@markdown Monte Google Drive para cargar modelos previamente entrenados y guardar los resultados.

#@markdown 

#@markdown 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@title Instalación
#@markdown StyleGAN2-ADA será instalada en su Google Drive para acelerar el proceso de entrenamiento.

#@markdown Ejecute esta celda. Si ya ha instalado el repositorio, se omitirá el proceso de instalación y actualizará el directorio del repositorio. Si no lo ha instalado, instalará todos los archivos necesarios.
import os
import shlex

# !pip install numpy==1.22.4
import numpy as np


if os.path.isdir("/content/drive/MyDrive/colab-sg2-ada-pytorch"):
    # %cd "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
elif os.path.isdir("/content/drive/"):
    #install script
    # %cd "/content/drive/MyDrive/"
    # !mkdir colab-sg2-ada-pytorch
    # %cd colab-sg2-ada-pytorch
    # !git clone https://github.com/dvschultz/stylegan2-ada-pytorch
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU -O /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl
else:
    # !git clone https://github.com/dvschultz/stylegan2-ada-pytorch
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # %cd pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU
    # %cd ../

# !pip install ninja opensimplex

# %cd "/content/drive/My Drive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git pull
# !git stash
# !git checkout origin/main -- train.py generate.py legacy.py closed_form_factorization.py flesh_digression.py apply_factor.py README.md calc_metrics.py training/stylegan2_multi.py training/training_loop.py util/utilgan.py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy==1.22.4 in /usr/local/lib/python3.8/dist-packages (1.22.4)
# /content/drive/.shortcut-targets-by-id/1mYE5u3HR8Hck8XmbTUymPzCi6NFlWojw/colab-sg2-ada-pytorch/stylegan2-ada-pytorch
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ninja in /usr/local/lib/python3.8/dist-packages (1.11.1)
# Requirement already satisfied: opensimplex in /usr/local/lib/python3.8/dist-packages (0.4.3)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.8/dist-packages (from opensimplex) (1.22.4)
# /content/drive/.shortcut-targets-by-id/1mYE5u3HR8Hck8XmbTUymPzCi6NFlWojw/colab-sg2-ada-pytorch/stylegan2-ada-pytorch
# Already up to date.
# Saved working directory and index state WIP on main: bbc87df Add files via upload

# %% [markdown]
# # Generación

# %%
#@title Generación de Imágenes
#@markdown Directorio para guardar las imágenes generadas
outdir = "/content/drive/MyDrive/ResultadosGAN/coral/net16-2" #@param {type: "string"}
#@markdown Ruta al modelo preentrenado. La forma más sencilla es buscar el archivo en el directorio del Drive que se encuentra en el panel de la izquierda, hacer clic en los tres puntos y escoger la opción `copy path`, luego pegarlo aquí:
network = "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/00070-amonites-11gb-gpu-noaug-resumecustom/network-snapshot-000020.pkl" #@param {type: "string"}
#@markdown ---
#@markdown **Parámetros de Generación**

#@markdown El "truncamiento", digamos que *redondea o trunca* los valores del espacio latente. Esto puede tener un efecto sutil o dramático en sus imágenes dependiendo del valor que utilice. Cuanto menor sea el número, más realistas deberían aparecer sus imágenes, pero esto también afectará la diversidad. La mayoría de la gente elige entre 0.5 y 1.0, pero técnicamente es infinito.
truncation =   0.8#@param {type: "number"}
#@markdown Esto le permite elegir semillas (seeds) aleatorias del modelo. Recuerde que nuestra entrada a StyleGAN es una matriz de 512 dimensiones. Estas semillas generarán esos 512 valores. Cada semilla generará una matriz aleatoria diferente. El mismo valor de inicialización también generará siempre la misma matriz aleatoria, por lo que luego podemos usarla para otros fines, como la interpolación.
#@markdown 
#@markdown Proporcione un número, una lista de enteros separados por comas o un rango entre valores utilizando un guión.
seeds = "1200-1250" #@param {type: "string"}
#@markdown Generación de imágenes aleatorias (se ignorará el parámetro de semillas)
gen_random = True #@param {type: "boolean"}
#@markdown Cantidad de imágenes aleatorias a generar
n_imgs = 20 #@param {type: "integer"}
#@markdown ---
#@markdown **Generación de imágenes no-cuadradas**

#@markdown Es posible hacer que el modelo genere imágenes que no sean cuadradas. Esto no es tan bueno como entrenar un modelo rectangular, pero con el modelo correcto aún puede verse bien.
gen_nonsquare = False #@param {type: "boolean"}
#@markdown Ancho
width = 640 #@param {type: "integer"}
#@markdown Alto
height = 480 #@param {type: "integer"}
#@markdown Estilo de relleno para aplicar en el espacio adicional.
scale_type = 'pad' #@param ['pad', 'padside', 'symm', 'symmside']


if gen_random:
  seeds = ','.join(str(s) for s in list(set(list(np.random.randint(4294967295, size=n_imgs)))))
else:
  seeds = ','.join(str(s).strip() for s in seeds.split(','))
print("Seeds: ", seeds)

nonsquare = f'--size={width}-{height} --scale-type={scale_type}' if gen_nonsquare else ''


outdir = shlex.quote(outdir)
network = shlex.quote(network)
# !python generate.py --outdir={outdir} --trunc={truncation} --seeds={seeds} --network={network} {nonsquare}
# Out:
# Seeds:  1736448146,1553489685,2812788118,2397732248,4037828505,1350401949,867131686,3401379878,1423035819,1463073454,2091350319,2963161799,600388809,3137402954,2488083403,2166291404,4260462678,3780083575,1160344187,1882444030
# generate.py:59: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   elif(len(seeds) is not 3):
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/00070-amonites-11gb-gpu-noaug-resumecustom/network-snapshot-000020.pkl"...
# Generating image for seed 1736448146 (0/20) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 1553489685 (1/20) ...
# Generating image for seed 2812788118 (2/20) ...
# Generating image for seed 2397732248 (3/20) ...
# Generating image for seed 4037828505 (4/20) ...
# Generating image for seed 1350401949 (5/20) ...
# Generating image for seed 867131686 (6/20) ...
# Generating image for seed 3401379878 (7/20) ...
# Generating image for seed 1423035819 (8/20) ...
# Generating image for seed 1463073454 (9/20) ...
# Generating image for seed 2091350319 (10/20) ...
# Generating image for seed 2963161799 (11/20) ...
# Generating image for seed 600388809 (12/20) ...
# Generating image for seed 3137402954 (13/20) ...
# Generating image for seed 2488083403 (14/20) ...
# Generating image for seed 2166291404 (15/20) ...
# Generating image for seed 4260462678 (16/20) ...
# Generating image for seed 3780083575 (17/20) ...
# Generating image for seed 1160344187 (18/20) ...
# Generating image for seed 1882444030 (19/20) ...

# %%
#@title Truncamiento Transversal

#@markdown A continuación, puede tomar una semilla y ver los cambios en ella en cualquier cantidad de truncamiento. -1 a 1 serán imágenes bastante realistas, pero cuanto más te alejas, más extrañas se vuelven.

#@markdown Directorio para guardar las imágenes generadas
outdir = "/content/drive/MyDrive/ResultadosGAN/coral/net16-trunc4" #@param {type: "string"}
#@markdown Ruta al modelo preentrenado. La forma más sencilla es buscar el archivo en el directorio del Drive que se encuentra en el panel de la izquierda, hacer clic en los tres puntos y escoger la opción `copy path`, luego pegarlo aquí:
network = "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/00000-coral-bleached-ver-11gb-gpu-noaug-resumeffhq512/network-snapshot-000016.pkl" #@param {type: "string"}

#@markdown Escoja solo una semilla. Elija una favorita de sus imágenes generadas.
seed = 939915100  #@param {type: "integer"}
#@markdown Valor de truncamiento inicial.
start =   0#@param {type: "number"}
#@markdown Valor donde se detiene el truncamiento. Debe ser mayor que el valor inicial. (Ocurrirá un error si no es así)
stop = 1.5  #@param {type: "number"}
#@markdown Cuánto debe incrementar cada fotograma el valor de truncamiento. Coloque un valor muy pequeño si desea una interpolación larga y lenta. (parada-inicio / incremento = fotogramas totales)
increment = 0.005  #@param {type: "number"}

outdir = shlex.quote(outdir)
network = shlex.quote(network)
# !python generate.py --process="truncation" --outdir={outdir} --start={start} --stop={stop} --increment={increment} --seeds={seed} --network={network}

# %%
#@title Interpolación
#@markdown Directorio para guardar las imágenes generadas
outdir = "/content/drive/MyDrive/ResultadosGAN/coral/net16-int2" #@param {type: "string"}
#@markdown Ruta al modelo preentrenado. La forma más sencilla es buscar el archivo en el directorio del Drive que se encuentra en el panel de la izquierda, hacer clic en los tres puntos y escoger la opción `copy path`, luego pegarlo aquí:
network = "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/00070-amonites-11gb-gpu-noaug-resumecustom/network-snapshot-000020.pkl" #@param {type: "string"}
#@markdown ---
#@markdown **Parámetros de Generación**

#@markdown El "truncamiento", digamos que redondea o trunca los valores del espacio latente. Esto puede tener un efecto sutil o dramático en sus imágenes dependiendo del valor que utilice. Cuanto menor sea el número, más realistas deberían aparecer sus imágenes, pero esto también afectará la diversidad. La mayoría de la gente elige entre 0.5 y 1.0, pero técnicamente es infinito.
truncation =  0.8#@param {type: "number"}
#@markdown Esto le permite elegir semillas (seeds) aleatorias del modelo. Recuerde que nuestra entrada a StyleGAN es una matriz de 512 dimensiones. Estas semillas generarán esos 512 valores. Cada semilla generará una matriz aleatoria diferente. El mismo valor de inicialización también generará siempre la misma matriz aleatoria, por lo que luego podemos usarla para otros fines, como la interpolación.
#@markdown 
#@markdown Proporcione un número, una lista de enteros separados por comas o un rango entre valores utilizando un guión.
seeds = "632,633,634,634,632" #@param {type: "string"}
#@markdown Generación de imágenes aleatorias (se ignorará el parámetro de semillas)
gen_random = False #@param {type: "boolean"}
#@markdown Cantidad de imágenes aleatorias a generar
n_imgs =  5#@param {type: "integer"}
gen_loop = False 
#@markdown ---
#@markdown **Parámetros de Interpolación**
#@markdown
#@markdown Número de cuadros (frames) por imagen
frames = 120 #@param {type: "integer"}

interpolation = 'linear' 
#@markdown Espacio latente
space = 'z' #@param ['z', 'w']
#@markdown ---
#@markdown **Generación de imágenes no-cuadradas**

#@markdown Es posible hacer que el modelo genere imágenes que no sean cuadradas. Esto no es tan bueno como entrenar un modelo rectangular, pero con el modelo correcto aún puede verse bien.
gen_nonsquare = False #@param {type: "boolean"}
#@markdown Ancho
width = 480 #@param {type: "integer"}
#@markdown Alto
height = 720 #@param {type: "integer"}
#@markdown Estilo de relleno para aplicar en el espacio adicional.
scale_type = 'padside' #@param ['pad', 'padside', 'symm', 'symmside']


if gen_random:
  seeds = list(set(list(np.random.randint(4294967295, size=n_imgs))))
  if gen_loop:
    seeds.append(seeds[-1])
  seeds = ','.join(str(s) for s in seeds)
else:
  seeds = ','.join(str(s).strip() for s in seeds.split(','))
print("Seeds: ", seeds)

nonsquare = f'--size={width}-{height} --scale-type={scale_type}' if gen_nonsquare else ''

outdir = shlex.quote(outdir)
network = shlex.quote(network)
# !python generate.py --outdir={outdir} --trunc={truncation} --seeds={seeds} --network={network} {nonsquare} --space={space} --process="interpolation" --interpolation={interpolation} --frames={frames}
# Out:
# Seeds:  632,633,634,634,632
# generate.py:59: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   elif(len(seeds) is not 3):
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/00070-amonites-11gb-gpu-noaug-resumecustom/network-snapshot-000020.pkl"...
# Generating image for frame 0/480 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/480 ...
# Generating image for frame 2/480 ...
# Generating image for frame 3/480 ...
# Generating image for frame 4/480 ...
# Generating image for frame 5/480 ...
# Generating image for frame 6/480 ...
# Generating image for frame 7/480 ...
# Generating image for frame 8/480 ...
# Generating image for frame 9/480 ...
# Generating image for frame 10/480 ...
# Generating image for frame 11/480 ...
# Generating image for frame 12/480 ...
# Generating image for frame 13/480 ...
# Generating image for frame 14/480 ...
# Generating image for frame 15/480 ...
# Generating image for frame 16/480 ...
# Generating image for frame 17/480 ...
# Generating image for frame 18/480 ...
# Generating image for frame 19/480 ...
# Generating image for frame 20/480 ...
# Generating image for frame 21/480 ...
# Generating image for frame 22/480 ...
# Generating image for frame 23/480 ...
# Generating image for frame 24/480 ...
# Generating image for frame 25/480 ...
# Generating image for frame 26/480 ...
# Generating image for frame 27/480 ...
# Generating image for frame 28/480 ...
# Generating image for frame 29/480 ...
# Generating image for frame 30/480 ...
# Generating image for frame 31/480 ...
# Generating image for frame 32/480 ...
# Generating image for frame 33/480 ...
# Generating image for frame 34/480 ...
# Generating image for frame 35/480 ...
# Generating image for frame 36/480 ...
# Generating image for frame 37/480 ...
# Generating image for frame 38/480 ...
# Generating image for frame 39/480 ...
# Generating image for frame 40/480 ...
# Generating image for frame 41/480 ...
# Generating image for frame 42/480 ...
# Generating image for frame 43/480 ...
# Generating image for frame 44/480 ...
# Generating image for frame 45/480 ...
# Generating image for frame 46/480 ...
# Generating image for frame 47/480 ...
# Generating image for frame 48/480 ...
# Generating image for frame 49/480 ...
# Generating image for frame 50/480 ...
# Generating image for frame 51/480 ...
# Generating image for frame 52/480 ...
# Generating image for frame 53/480 ...
# Generating image for frame 54/480 ...
# Generating image for frame 55/480 ...
# Generating image for frame 56/480 ...
# Generating image for frame 57/480 ...
# Generating image for frame 58/480 ...
# Generating image for frame 59/480 ...
# Generating image for frame 60/480 ...
# Generating image for frame 61/480 ...
# Generating image for frame 62/480 ...
# Generating image for frame 63/480 ...
# Generating image for frame 64/480 ...
# Generating image for frame 65/480 ...
# Generating image for frame 66/480 ...
# Generating image for frame 67/480 ...
# Generating image for frame 68/480 ...
# Generating image for frame 69/480 ...
# Generating image for frame 70/480 ...
# Generating image for frame 71/480 ...
# Generating image for frame 72/480 ...
# Generating image for frame 73/480 ...
# Generating image for frame 74/480 ...
# Generating image for frame 75/480 ...
# Generating image for frame 76/480 ...
# Generating image for frame 77/480 ...
# Generating image for frame 78/480 ...
# Generating image for frame 79/480 ...
# Generating image for frame 80/480 ...
# Generating image for frame 81/480 ...
# Generating image for frame 82/480 ...
# Generating image for frame 83/480 ...
# Generating image for frame 84/480 ...
# Generating image for frame 85/480 ...
# Generating image for frame 86/480 ...
# Generating image for frame 87/480 ...
# Generating image for frame 88/480 ...
# Generating image for frame 89/480 ...
# Generating image for frame 90/480 ...
# Generating image for frame 91/480 ...
# Generating image for frame 92/480 ...
# Generating image for frame 93/480 ...
# Generating image for frame 94/480 ...
# Generating image for frame 95/480 ...
# Generating image for frame 96/480 ...
# Generating image for frame 97/480 ...
# Generating image for frame 98/480 ...
# Generating image for frame 99/480 ...
# Generating image for frame 100/480 ...
# Generating image for frame 101/480 ...
# Generating image for frame 102/480 ...
# Generating image for frame 103/480 ...
# Generating image for frame 104/480 ...
# Generating image for frame 105/480 ...
# Generating image for frame 106/480 ...
# Generating image for frame 107/480 ...
# Generating image for frame 108/480 ...
# Generating image for frame 109/480 ...
# Generating image for frame 110/480 ...
# Generating image for frame 111/480 ...
# Generating image for frame 112/480 ...
# Generating image for frame 113/480 ...
# Generating image for frame 114/480 ...
# Generating image for frame 115/480 ...
# Generating image for frame 116/480 ...
# Generating image for frame 117/480 ...
# Generating image for frame 118/480 ...
# Generating image for frame 119/480 ...
# Generating image for frame 120/480 ...
# Generating image for frame 121/480 ...
# Generating image for frame 122/480 ...
# Generating image for frame 123/480 ...
# Generating image for frame 124/480 ...
# Generating image for frame 125/480 ...
# Generating image for frame 126/480 ...
# Generating image for frame 127/480 ...
# Generating image for frame 128/480 ...
# Generating image for frame 129/480 ...
# Generating image for frame 130/480 ...
# Generating image for frame 131/480 ...
# Generating image for frame 132/480 ...
# Generating image for frame 133/480 ...
# Generating image for frame 134/480 ...
# Generating image for frame 135/480 ...
# Generating image for frame 136/480 ...
# Generating image for frame 137/480 ...
# Generating image for frame 138/480 ...
# Generating image for frame 139/480 ...
# Generating image for frame 140/480 ...
# Generating image for frame 141/480 ...
# Generating image for frame 142/480 ...
# Generating image for frame 143/480 ...
# Generating image for frame 144/480 ...
# Generating image for frame 145/480 ...
# Generating image for frame 146/480 ...
# Generating image for frame 147/480 ...
# Generating image for frame 148/480 ...
# Generating image for frame 149/480 ...
# Generating image for frame 150/480 ...
# Generating image for frame 151/480 ...
# Generating image for frame 152/480 ...
# Generating image for frame 153/480 ...
# Generating image for frame 154/480 ...
# Generating image for frame 155/480 ...
# Generating image for frame 156/480 ...
# Generating image for frame 157/480 ...
# Generating image for frame 158/480 ...
# Generating image for frame 159/480 ...
# Generating image for frame 160/480 ...
# Generating image for frame 161/480 ...
# Generating image for frame 162/480 ...
# Generating image for frame 163/480 ...
# Generating image for frame 164/480 ...
# Generating image for frame 165/480 ...
# Generating image for frame 166/480 ...
# Generating image for frame 167/480 ...
# Generating image for frame 168/480 ...
# Generating image for frame 169/480 ...
# Generating image for frame 170/480 ...
# Generating image for frame 171/480 ...
# Generating image for frame 172/480 ...
# Generating image for frame 173/480 ...
# Generating image for frame 174/480 ...
# Generating image for frame 175/480 ...
# Generating image for frame 176/480 ...
# Generating image for frame 177/480 ...
# Generating image for frame 178/480 ...
# Generating image for frame 179/480 ...
# Generating image for frame 180/480 ...
# Generating image for frame 181/480 ...
# Generating image for frame 182/480 ...
# Generating image for frame 183/480 ...
# Generating image for frame 184/480 ...
# Generating image for frame 185/480 ...
# Generating image for frame 186/480 ...
# Generating image for frame 187/480 ...
# Generating image for frame 188/480 ...
# Generating image for frame 189/480 ...
# Generating image for frame 190/480 ...
# Generating image for frame 191/480 ...
# Generating image for frame 192/480 ...
# Generating image for frame 193/480 ...
# Generating image for frame 194/480 ...
# Generating image for frame 195/480 ...
# Generating image for frame 196/480 ...
# Generating image for frame 197/480 ...
# Generating image for frame 198/480 ...
# Generating image for frame 199/480 ...
# Generating image for frame 200/480 ...
# Generating image for frame 201/480 ...
# Generating image for frame 202/480 ...
# Generating image for frame 203/480 ...
# Generating image for frame 204/480 ...
# Generating image for frame 205/480 ...
# Generating image for frame 206/480 ...
# Generating image for frame 207/480 ...
# Generating image for frame 208/480 ...
# Generating image for frame 209/480 ...
# Generating image for frame 210/480 ...
# Generating image for frame 211/480 ...
# Generating image for frame 212/480 ...
# Generating image for frame 213/480 ...
# Generating image for frame 214/480 ...
# Generating image for frame 215/480 ...
# Generating image for frame 216/480 ...
# Generating image for frame 217/480 ...
# Generating image for frame 218/480 ...
# Generating image for frame 219/480 ...
# Generating image for frame 220/480 ...
# Generating image for frame 221/480 ...
# Generating image for frame 222/480 ...
# Generating image for frame 223/480 ...
# Generating image for frame 224/480 ...
# Generating image for frame 225/480 ...
# Generating image for frame 226/480 ...
# Generating image for frame 227/480 ...
# Generating image for frame 228/480 ...
# Generating image for frame 229/480 ...
# Generating image for frame 230/480 ...
# Generating image for frame 231/480 ...
# Generating image for frame 232/480 ...
# Generating image for frame 233/480 ...
# Generating image for frame 234/480 ...
# Generating image for frame 235/480 ...
# Generating image for frame 236/480 ...
# Generating image for frame 237/480 ...
# Generating image for frame 238/480 ...
# Generating image for frame 239/480 ...
# Generating image for frame 240/480 ...
# Generating image for frame 241/480 ...
# Generating image for frame 242/480 ...
# Generating image for frame 243/480 ...
# Generating image for frame 244/480 ...
# Generating image for frame 245/480 ...
# Generating image for frame 246/480 ...
# Generating image for frame 247/480 ...
# Generating image for frame 248/480 ...
# Generating image for frame 249/480 ...
# Generating image for frame 250/480 ...
# Generating image for frame 251/480 ...
# Generating image for frame 252/480 ...
# Generating image for frame 253/480 ...
# Generating image for frame 254/480 ...
# Generating image for frame 255/480 ...
# Generating image for frame 256/480 ...
# Generating image for frame 257/480 ...
# Generating image for frame 258/480 ...
# Generating image for frame 259/480 ...
# Generating image for frame 260/480 ...
# Generating image for frame 261/480 ...
# Generating image for frame 262/480 ...
# Generating image for frame 263/480 ...
# Generating image for frame 264/480 ...
# Generating image for frame 265/480 ...
# Generating image for frame 266/480 ...
# Generating image for frame 267/480 ...
# Generating image for frame 268/480 ...
# Generating image for frame 269/480 ...
# Generating image for frame 270/480 ...
# Generating image for frame 271/480 ...
# Generating image for frame 272/480 ...
# Generating image for frame 273/480 ...
# Generating image for frame 274/480 ...
# Generating image for frame 275/480 ...
# Generating image for frame 276/480 ...
# Generating image for frame 277/480 ...
# Generating image for frame 278/480 ...
# Generating image for frame 279/480 ...
# Generating image for frame 280/480 ...
# Generating image for frame 281/480 ...
# Generating image for frame 282/480 ...
# Generating image for frame 283/480 ...
# Generating image for frame 284/480 ...
# Generating image for frame 285/480 ...
# Generating image for frame 286/480 ...
# Generating image for frame 287/480 ...
# Generating image for frame 288/480 ...
# Generating image for frame 289/480 ...
# Generating image for frame 290/480 ...
# Generating image for frame 291/480 ...
# Generating image for frame 292/480 ...
# Generating image for frame 293/480 ...
# Generating image for frame 294/480 ...
# Generating image for frame 295/480 ...
# Generating image for frame 296/480 ...
# Generating image for frame 297/480 ...
# Generating image for frame 298/480 ...
# Generating image for frame 299/480 ...
# Generating image for frame 300/480 ...
# Generating image for frame 301/480 ...
# Generating image for frame 302/480 ...
# Generating image for frame 303/480 ...
# Generating image for frame 304/480 ...
# Generating image for frame 305/480 ...
# Generating image for frame 306/480 ...
# Generating image for frame 307/480 ...
# Generating image for frame 308/480 ...
# Generating image for frame 309/480 ...
# Generating image for frame 310/480 ...
# Generating image for frame 311/480 ...
# Generating image for frame 312/480 ...
# Generating image for frame 313/480 ...
# Generating image for frame 314/480 ...
# Generating image for frame 315/480 ...
# Generating image for frame 316/480 ...
# Generating image for frame 317/480 ...
# Generating image for frame 318/480 ...
# Generating image for frame 319/480 ...
# Generating image for frame 320/480 ...
# Generating image for frame 321/480 ...
# Generating image for frame 322/480 ...
# Generating image for frame 323/480 ...
# Generating image for frame 324/480 ...
# Generating image for frame 325/480 ...
# Generating image for frame 326/480 ...
# Generating image for frame 327/480 ...
# Generating image for frame 328/480 ...
# Generating image for frame 329/480 ...
# Generating image for frame 330/480 ...
# Generating image for frame 331/480 ...
# Generating image for frame 332/480 ...
# Generating image for frame 333/480 ...
# Generating image for frame 334/480 ...
# Generating image for frame 335/480 ...
# Generating image for frame 336/480 ...
# Generating image for frame 337/480 ...
# Generating image for frame 338/480 ...
# Generating image for frame 339/480 ...
# Generating image for frame 340/480 ...
# Generating image for frame 341/480 ...
# Generating image for frame 342/480 ...
# Generating image for frame 343/480 ...
# Generating image for frame 344/480 ...
# Generating image for frame 345/480 ...
# Generating image for frame 346/480 ...
# Generating image for frame 347/480 ...
# Generating image for frame 348/480 ...
# Generating image for frame 349/480 ...
# Generating image for frame 350/480 ...
# Generating image for frame 351/480 ...
# Generating image for frame 352/480 ...
# Generating image for frame 353/480 ...
# Generating image for frame 354/480 ...
# Generating image for frame 355/480 ...
# Generating image for frame 356/480 ...
# Generating image for frame 357/480 ...
# Generating image for frame 358/480 ...
# Generating image for frame 359/480 ...
# Generating image for frame 360/480 ...
# Generating image for frame 361/480 ...
# Generating image for frame 362/480 ...
# Generating image for frame 363/480 ...
# Generating image for frame 364/480 ...
# Generating image for frame 365/480 ...
# Generating image for frame 366/480 ...
# Generating image for frame 367/480 ...
# Generating image for frame 368/480 ...
# Generating image for frame 369/480 ...
# Generating image for frame 370/480 ...
# Generating image for frame 371/480 ...
# Generating image for frame 372/480 ...
# Generating image for frame 373/480 ...
# Generating image for frame 374/480 ...
# Generating image for frame 375/480 ...
# Generating image for frame 376/480 ...
# Generating image for frame 377/480 ...
# Generating image for frame 378/480 ...
# Generating image for frame 379/480 ...
# Generating image for frame 380/480 ...
# Generating image for frame 381/480 ...
# Generating image for frame 382/480 ...
# Generating image for frame 383/480 ...
# Generating image for frame 384/480 ...
# Generating image for frame 385/480 ...
# Generating image for frame 386/480 ...
# Generating image for frame 387/480 ...
# Generating image for frame 388/480 ...
# Generating image for frame 389/480 ...
# Generating image for frame 390/480 ...
# Generating image for frame 391/480 ...
# Generating image for frame 392/480 ...
# Generating image for frame 393/480 ...
# Generating image for frame 394/480 ...
# Generating image for frame 395/480 ...
# Generating image for frame 396/480 ...
# Generating image for frame 397/480 ...
# Generating image for frame 398/480 ...
# Generating image for frame 399/480 ...
# Generating image for frame 400/480 ...
# Generating image for frame 401/480 ...
# Generating image for frame 402/480 ...
# Generating image for frame 403/480 ...
# Generating image for frame 404/480 ...
# Generating image for frame 405/480 ...
# Generating image for frame 406/480 ...
# Generating image for frame 407/480 ...
# Generating image for frame 408/480 ...
# Generating image for frame 409/480 ...
# Generating image for frame 410/480 ...
# Generating image for frame 411/480 ...
# Generating image for frame 412/480 ...
# Generating image for frame 413/480 ...
# Generating image for frame 414/480 ...
# Generating image for frame 415/480 ...
# Generating image for frame 416/480 ...
# Generating image for frame 417/480 ...
# Generating image for frame 418/480 ...
# Generating image for frame 419/480 ...
# Generating image for frame 420/480 ...
# Generating image for frame 421/480 ...
# Generating image for frame 422/480 ...
# Generating image for frame 423/480 ...
# Generating image for frame 424/480 ...
# Generating image for frame 425/480 ...
# Generating image for frame 426/480 ...
# Generating image for frame 427/480 ...
# Generating image for frame 428/480 ...
# Generating image for frame 429/480 ...
# Generating image for frame 430/480 ...
# Generating image for frame 431/480 ...
# Generating image for frame 432/480 ...
# Generating image for frame 433/480 ...
# Generating image for frame 434/480 ...
# Generating image for frame 435/480 ...
# Generating image for frame 436/480 ...
# Generating image for frame 437/480 ...
# Generating image for frame 438/480 ...
# Generating image for frame 439/480 ...
# Generating image for frame 440/480 ...
# Generating image for frame 441/480 ...
# Generating image for frame 442/480 ...
# Generating image for frame 443/480 ...
# Generating image for frame 444/480 ...
# Generating image for frame 445/480 ...
# Generating image for frame 446/480 ...
# Generating image for frame 447/480 ...
# Generating image for frame 448/480 ...
# Generating image for frame 449/480 ...
# Generating image for frame 450/480 ...
# Generating image for frame 451/480 ...
# Generating image for frame 452/480 ...
# Generating image for frame 453/480 ...
# Generating image for frame 454/480 ...
# Generating image for frame 455/480 ...
# Generating image for frame 456/480 ...
# Generating image for frame 457/480 ...
# Generating image for frame 458/480 ...
# Generating image for frame 459/480 ...
# Generating image for frame 460/480 ...
# Generating image for frame 461/480 ...
# Generating image for frame 462/480 ...
# Generating image for frame 463/480 ...
# Generating image for frame 464/480 ...
# Generating image for frame 465/480 ...
# Generating image for frame 466/480 ...
# Generating image for frame 467/480 ...
# Generating image for frame 468/480 ...
# Generating image for frame 469/480 ...
# Generating image for frame 470/480 ...
# Generating image for frame 471/480 ...
# Generating image for frame 472/480 ...
# Generating image for frame 473/480 ...
# Generating image for frame 474/480 ...
# Generating image for frame 475/480 ...
# Generating image for frame 476/480 ...
# Generating image for frame 477/480 ...
# Generating image for frame 478/480 ...
# Generating image for frame 479/480 ...
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/drive/MyDrive/ResultadosGAN/coral/net16-int2/frames/frame%04d.png':
#   Duration: 00:00:19.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x558464477e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x558464477e00] profile High, level 3.2
# [libx264 @ 0x558464477e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/ResultadosGAN/coral/net16-int2/interpolation-linear-seeds_632_633_634_634_632-24fps.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 24 fps, 12288 tbn, 24 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  480 fps= 13 q=-1.0 Lsize=    5167kB time=00:00:19.87 bitrate=2129.9kbits/s speed=0.527x
# video:5162kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.103063%
# [libx264 @ 0x558464477e00] frame I:2     Avg QP:17.65  size:116834
# [libx264 @ 0x558464477e00] frame P:254   Avg QP:22.28  size: 18257
# [libx264 @ 0x558464477e00] frame B:224   Avg QP:25.42  size:  1850
# [libx264 @ 0x558464477e00] consecutive B-frames: 35.6%  5.0%  4.4% 55.0%
# [libx264 @ 0x558464477e00] mb I  I16..4:  4.0% 81.5% 14.5%
# [libx264 @ 0x558464477e00] mb P  I16..4:  1.2%  4.0%  0.3%  P16..4: 41.1% 13.4%  8.9%  0.0%  0.0%    skip:31.1%
# [libx264 @ 0x558464477e00] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 12.4%  0.8%  0.2%  direct: 1.5%  skip:84.9%  L0:18.1% L1:65.7% BI:16.1%
# [libx264 @ 0x558464477e00] 8x8 transform intra:74.4% inter:71.0%
# [libx264 @ 0x558464477e00] coded y,uvDC,uvAC intra: 60.2% 56.9% 18.9% inter: 19.2% 17.7% 1.1%
# [libx264 @ 0x558464477e00] i16 v,h,dc,p: 16% 16%  8% 61%
# [libx264 @ 0x558464477e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 15% 21%  6%  9%  9%  9%  7%  7%
# [libx264 @ 0x558464477e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 13% 10%  7% 14% 12% 11%  8%  7%
# [libx264 @ 0x558464477e00] i8c dc,h,v,p: 60% 18% 15%  6%
# [libx264 @ 0x558464477e00] Weighted P-Frames: Y:17.7% UV:9.8%
# [libx264 @ 0x558464477e00] ref P L0: 65.0% 27.0%  6.5%  1.3%  0.2%
# [libx264 @ 0x558464477e00] ref B L0: 94.3%  4.6%  1.2%
# [libx264 @ 0x558464477e00] ref B L1: 99.5%  0.5%
# [libx264 @ 0x558464477e00] kb/s:2114.15

# %%
#@title Bucles de Interpolación
#@markdown Directorio para guardar las imágenes generadas
outdir = "/content/drive/MyDrive/ResultadosGAN/coral/net16-bucle2" #@param {type: "string"}
#@markdown Ruta al modelo preentrenado. La forma más sencilla es buscar el archivo en el directorio del Drive que se encuentra en el panel de la izquierda, hacer clic en los tres puntos y escoger la opción `copy path`, luego pegarlo aquí:
network = "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/00000-coral-bleached-ver-11gb-gpu-noaug-resumeffhq512/network-snapshot-000016.pkl" #@param {type: "string"}
#@markdown ---
#@markdown **Parámetros de Generación**

#@markdown El "truncamiento", digamos que redondea o trunca los valores del espacio latente. Esto puede tener un efecto sutil o dramático en sus imágenes dependiendo del valor que utilice. Cuanto menor sea el número, más realistas deberían aparecer sus imágenes, pero esto también afectará la diversidad. La mayoría de la gente elige entre 0.5 y 1.0, pero técnicamente es infinito.
truncation =  0.9#@param {type: "number"}

#@markdown ---
#@markdown **Parámetros de Interpolación**


interpolation = 'circularloop'
#@markdown Número de cuadros (frames)
frames =  720#@param {type: "integer"}
#@markdown Esto controla qué tan "amplio" es el bucle. Hágalo más pequeño para mostrar una gama menos diversa de muestras o más grande para cubrir muchas muestras. Estos `frames` adicionales pueden ayudar a determinar qué tan rápido se siente el video.
diameter =  1000#@param {type: "number"}
#@markdown Lugar de inicio en el espacio z. Nota: este valor no tiene nada que ver con las semillas que usa para generar imágenes. Solo te permite aleatorizar tu punto de inicio.
random_seed = 800 #@param {type: "integer"}

#@markdown ---
#@markdown **Generación de imágenes no-cuadradas**

#@markdown Es posible hacer que el modelo genere imágenes que no sean cuadradas. Esto no es tan bueno como entrenar un modelo rectangular, pero con el modelo correcto aún puede verse bien.
gen_nonsquare = False #@param {type: "boolean"}
#@markdown Ancho
width = 480 #@param {type: "integer"}
#@markdown Alto
height = 640 #@param {type: "integer"}
#@markdown Estilo de relleno para aplicar en el espacio adicional.
scale_type = 'symm' #@param ['pad', 'padside', 'symm', 'symmside']


nonsquare = f'--size={width}-{height} --scale-type={scale_type}' if gen_nonsquare else ''

outdir = shlex.quote(outdir)
network = shlex.quote(network)
# !python generate.py --outdir={outdir} --trunc={truncation} --network={network} {nonsquare} --process="interpolation" --interpolation={interpolation} --diameter={diameter} --random_seed={random_seed} --frames={frames}
